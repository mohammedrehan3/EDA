# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ft=pd.read_csv(r"C:\datasets\footbal.csv")
ft.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
ft.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
ft.shape
# Out:
# (18278, 104)

# %%
ft.size
# Out:
# 1900912

# %%
ft.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
for col in ft.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
ft['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
ft['nationality'].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.bar(list(ft['nationality'].value_counts()[0:10].keys()),ft['nationality'].value_counts()[0:10],color='b')
plt.title('NATIONALITY')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.pie(ft['nationality'].value_counts()[0:10],labels=list(ft['nationality'].value_counts()[0:10].keys()),autopct='%1.1f%%',startangle=50)
plt.title('Nationality Contribution')
plt.show()

# %%
player_salary=ft[['short_name','wage_eur']]
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(15,10))
plt.bar(list(player_salary['short_name'][0:10]),list(player_salary['wage_eur'][0:10]),color='g')
plt.show()

# %%
ft['nationality']=='Argentina'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Argentina=ft[ft['nationality']=='Argentina']
Argentina.head()
# Out:
#     sofifa_id                                         player_url   short_name  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...     L. Messi
# 17     153079  https://sofifa.com/player/153079/sergio-aguero...    S. Agüero
# 23     211110  https://sofifa.com/player/211110/paulo-dybala/...    P. Dybala
# 66     183898  https://sofifa.com/player/183898/angel-di-mari...  A. Di María
# 93     201399  https://sofifa.com/player/201399/mauro-icardi/...    M. Icardi
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 0      Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
# 17  Sergio Leonel Agüero del Castillo   31  1988-06-02        173         70
# 23        Paulo Bruno Exequiel Dybala   25  1993-11-15        177         75
# 66    Ángel Fabián Di María Hernández   31  1988-02-14        180         69
# 93        Mauro Emanuel Icardi Rivero   26  1993-02-19        181         75
#
# ...

# %%
Argentina.sort_values(by=['height_cm'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 6542      223071  https://sofifa.com/player/223071/fernando-pell...
# 6067      222889  https://sofifa.com/player/222889/lucas-acevedo...
# 1786      205186  https://sofifa.com/player/205186/paulo-gazzani...
# 1141      152993  https://sofifa.com/player/152993/renato-civell...
# 519       179847  https://sofifa.com/player/179847/federico-fazi...
# ...          ...                                                ...
# 1923      170719  https://sofifa.com/player/170719/diego-buonano...
# 4552      190629  https://sofifa.com/player/190629/daniel-villal...
# 15878     241046  https://sofifa.com/player/241046/jonas-romero/...
# 1496      183895  https://sofifa.com/player/183895/maxi-moralez/...
# 4829      237994  https://sofifa.com/player/237994/nahuel-barrio...
#
#           short_name                        long_name  age         dob  \
# 6542   F. Pellegrino              Fernando Pellegrino   33  1986-03-31
# ...

# %%
Argentina.sort_values(by=['weight_kg'],ascending=False)
# Out:
#       sofifa_id                                         player_url  \
# 9006     235925  https://sofifa.com/player/235925/gaston-gomez/...
# 6067     222889  https://sofifa.com/player/222889/lucas-acevedo...
# 2174     227275  https://sofifa.com/player/227275/agustin-rossi...
# 682      176919  https://sofifa.com/player/176919/nahuel-guzman...
# 792      214979  https://sofifa.com/player/214979/juan-musso/20...
# ...         ...                                                ...
# 465      188988  https://sofifa.com/player/188988/manuel-lanzin...
# 2637     232517  https://sofifa.com/player/232517/nicolas-silva...
# 4829     237994  https://sofifa.com/player/237994/nahuel-barrio...
# 1923     170719  https://sofifa.com/player/170719/diego-buonano...
# 1496     183895  https://sofifa.com/player/183895/maxi-moralez/...
#
#          short_name                     long_name  age         dob  height_cm  \
# 9006       G. Gómez                  Gastón Gómez   23  1996-03-04        190
# ...

# %%
Argentina.sort_values(by=['short_name','wage_eur'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 15343     248139  https://sofifa.com/player/248139/yoel-juarez/2...
# 9941      245351  https://sofifa.com/player/245351/walter-perez/...
# 4403      224461  https://sofifa.com/player/224461/walter-montoy...
# 1890      139062  https://sofifa.com/player/139062/willy-caballe...
# 2821      224510  https://sofifa.com/player/224510/walter-bou/20...
# ...          ...                                                ...
# 8844      242317  https://sofifa.com/player/242317/alejo-antilef...
# 5661      242081  https://sofifa.com/player/242081/agustin-almen...
# 3498      215152  https://sofifa.com/player/215152/agustin-allio...
# 14174     242921  https://sofifa.com/player/242921/agustin-aleo/...
# 1372      215123  https://sofifa.com/player/215123/alan-aguerre/...
#
#          short_name                  long_name  age         dob  height_cm  \
# ...

# %%
Argentina=Argentina[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False)

# %%
plt.figure(figsize=(15,10))
plt.bar(list(Argentina['short_name'].value_counts().keys()[0:10]),list(Argentina['wage_eur'][0:10]),color='r')
plt.show()

# %%
player_shooting=ft[['short_name','shooting']]
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
player_defending=ft[['short_name','defending','nationality','club','wage_eur']]
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club  wage_eur
# 16  G. Chiellini       90.0        Italy           Juventus    215000
# 7    V. van Dijk       90.0  Netherlands          Liverpool    200000
# 11  K. Koulibaly       89.0      Senegal             Napoli    150000
# 35      D. Godín       89.0      Uruguay              Inter    135000
# 49    M. Hummels       89.0      Germany  Borussia Dortmund    130000
